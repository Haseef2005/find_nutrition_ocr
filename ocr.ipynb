# %%
from PIL import Image
from PIL import ImageOps
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

class find_nutrition:
    def __init__(self, image, text: list):
        self.image = image
        self.text = text

        
    def ocr(self):
        data = pytesseract.image_to_data(self.image, output_type=pytesseract.Output.DICT)
        for i, word in enumerate(data['text']):
            if word.strip():  # Filter out empty results
                print(f"Word: {word}, Confidence: {data['conf'][i]}, Bounding Box: {data['left'][i]}, {data['top'][i]}, {data['width'][i]}, {data['height'][i]}")


    def plain_text_ocr(self):
        text_ocr = pytesseract.image_to_string(self.image)
        print(text_ocr)


    def find_text_ocr(self):
        found = False
        data = pytesseract.image_to_data(self.image, output_type=pytesseract.Output.DICT)
        for i, word in enumerate(data['text']):
            if word.strip():  # Filter out empty results
                for j in self.text:
                    j = j.lower()
                    word = word.lower()
                    if j in word:
                        found = True
                        print(f"Word: {word}, Confidence: {data['conf'][i]}, Bounding Box: {data['left'][i]}, {data['top'][i]}, {data['width'][i]}, {data['height'][i]}")
        if not found:
            print("Nutrition not found, Please check the label by yourself again before you eat.")

# %%
# Example Usage
image_path = './images/n5.webp'
image = Image.open(image_path)
find_text = ['fat', 'Protein']

nutrition = find_nutrition(image, find_text)
nutrition.find_text_ocr()
# Out:
# Word: fat, Confidence: 82, Bounding Box: 182, 203, 15, 9
# Word: fat, Confidence: 60, Bounding Box: 208, 209, 14, 31
# Word: fat, Confidence: 68, Bounding Box: 191, 237, 12, 9
# Word: proteina, Confidence: 17, Bounding Box: 157, 359, 46, 12

# %%
nutrition.ocr()
# Out:
# Word: Nutrition, Confidence: 96, Bounding Box: 148, 75, 112, 22
# Word: Facts, Confidence: 96, Bounding Box: 270, 75, 71, 27
# Word: onan, Confidence: 38, Bounding Box: 350, 101, 35, 8
# Word: a, Confidence: 33, Bounding Box: 390, 103, 14, 6
# Word: about, Confidence: 91, Bounding Box: 148, 105, 29, 11
# Word: 5, Confidence: 95, Bounding Box: 181, 104, 7, 11
# Word: servings, Confidence: 96, Bounding Box: 192, 106, 47, 11
# Word: per, Confidence: 96, Bounding Box: 244, 106, 18, 11
# Word: container, Confidence: 80, Bounding Box: 266, 104, 53, 13
# Word: |, Confidence: 61, Bounding Box: 334, 96, 10, 30
# Word: potas, Confidence: 9, Bounding Box: 349, 114, 53, 8
# Word: Mu, Confidence: 57, Bounding Box: 391, 96, 13, 30
# Word: Serving, Confidence: 92, Bounding Box: 149, 119, 48, 14
# Word: size, Confidence: 65, Bounding Box: 203, 118, 27, 12
# Word: _, Confidence: 65, Bounding Box: 235, 110, 7, 34
# Word: 3/4, Confidence: 94, Bounding Box: 247, 110, 17, 34
# Word: cup, Confidence: 96, Bounding Box: 272, 121, 21, 11
# Word: (170g), Confidence: 91, Bounding Box: 298, 119, 39, 14
# Word: |i, Confidence: 0, Bounding Box: 349, 123, 52, 17
# Word: |, Confidence: 49, Bounding Box: 148, 132, 272, 14
# Word: Ealories”, Confidence: 43, Bounding Box: 149, 148, 109, 29
# Word: 100]..., Confidence: 0, Bounding Box: 285, 153, 141, 30
# Word: Se, Confidence: 0, Bounding Box: 269, 176, 10, 28
# Word: Datty, Confidence: 0, Bounding Box: 281, 188, 23, 8
# Word: Veneer}, Confidence: 47, Bounding Box: 308, 188, 25, 7
# Word: north, Confidence: 0, Bounding Box: 367, 185, 64, 11
# Word: Using, Confidence: 57, Bounding Box: 356, 198, 79, 12
# Word: ng, Confidence: 50, Bounding Box: 394, 189, 19, 28
# Word: 8, Confidence: 39, Bounding Box: 429, 189, 10, 28
# Word: sonst, Confidence: 0, Bounding Box: 381, 212, 38, 9
# Word: Total, Confidence: 60, Bounding Box: 151, 203, 25, 9
# Word: Fat, Confidence: 82, Bounding Box: 182, 203, 15, 9
# Word: 259, Confidence: 94, Bounding Box: 202, 192, 18, 30
# Word: 3%, Confidence: 88, Bounding Box: 318, 203, 16, 9
# Word: Satualed, Confidence: 39, Bounding Box: 163, 220, 41, 9
# Word: Fat, Confidence: 60, Bounding Box: 208, 209, 14, 31
# Word: 1.59, Confidence: 60, Bounding Box: 213, 220, 30, 14
# Word: \, Confidence: 92, Bounding Box: 93, 233, 3, 8
# Word: “Trans, Confidence: 65, Bounding Box: 159, 226, 28, 30
# Word: Fat, Confidence: 68, Bounding Box: 191, 237, 12, 9
# Word: 0g, Confidence: 76, Bounding Box: 207, 237, 10, 11
# Word: holesterol, Confidence: 32, Bounding Box: 153, 254, 86, 12
# Word: ng, Confidence: 50, Bounding Box: 221, 243, 22, 31
# Word: Sodium, Confidence: 91, Bounding Box: 150, 260, 39, 31
# Word: 1109, Confidence: 27, Bounding Box: 193, 260, 28, 31
# Word: 3%|, Confidence: 44, Bounding Box: 316, 271, 15, 10
# Word: 6, Confidence: 23, Bounding Box: 352, 277, 7, 6
# Word: |, Confidence: 6, Bounding Box: 323, 254, 9, 10
# Word: 808, Confidence: 26, Bounding Box: 348, 250, 27, 8
# Word: Detar, Confidence: 34, Bounding Box: 166, 296, 24, 30
# Word: Fiber, Confidence: 74, Bounding Box: 197, 296, 22, 30
# Word: 0g, Confidence: 74, Bounding Box: 222, 307, 10, 11
# Word: 0%, Confidence: 76, Bounding Box: 315, 307, 15, 9
# Word: \, Confidence: 81, Bounding Box: 87, 323, 17, 24
# Word: Total, Confidence: 58, Bounding Box: 167, 313, 19, 30
# Word: Sugars, Confidence: 46, Bounding Box: 190, 313, 28, 30
# Word: 129, Confidence: 46, Bounding Box: 223, 325, 13, 10
# Word: \, Confidence: 36, Bounding Box: 88, 345, 6, 9
# Word: Incas, Confidence: 29, Bounding Box: 180, 342, 109, 11
# Word: Og, Confidence: 59, Bounding Box: 216, 331, 10, 30
# Word: Acied, Confidence: 26, Bounding Box: 231, 331, 25, 30
# Word: Suars, Confidence: 16, Bounding Box: 261, 342, 28, 11
# Word: 0%, Confidence: 36, Bounding Box: 314, 342, 15, 9
# Word: \, Confidence: 89, Bounding Box: 106, 354, 2, 10
# Word: Proteina, Confidence: 17, Bounding Box: 157, 359, 46, 12
# Word: 16%, Confidence: 82, Bounding Box: 308, 359, 20, 9
# Word: /, Confidence: 44, Bounding Box: 104, 387, 2, 4
# Word: Wann, Confidence: 63, Bounding Box: 160, 375, 28, 31
# Word: 17mg, Confidence: 0, Bounding Box: 194, 375, 32, 31
# Word: ©, Confidence: 76, Bounding Box: 241, 387, 1, 8
# Word: Cabin, Confidence: 0, Bounding Box: 251, 375, 29, 31
# Word: 2g, Confidence: 43, Bounding Box: 283, 386, 23, 11
# Word: 2%, Confidence: 73, Bounding Box: 311, 386, 14, 9
# Word: WZ, Confidence: 49, Bounding Box: 70, 394, 34, 37
# Word: ientimgits, Confidence: 0, Bounding Box: 159, 395, 50, 27
# Word: ©, Confidence: 40, Bounding Box: 227, 395, 14, 27
# Word: Potassum, Confidence: 23, Bounding Box: 247, 395, 41, 27
# Word: 360m, Confidence: 41, Bounding Box: 292, 395, 19, 27
# Word: 8, Confidence: 56, Bounding Box: 317, 395, 16, 27
# Word: 1\, Confidence: 22, Bounding Box: 66, 424, 14, 4
# Word: ain, Confidence: 71, Bounding Box: 165, 409, 18, 30
# Word: 106, Confidence: 30, Bounding Box: 193, 409, 23, 30
# Word: 1%, Confidence: 66, Bounding Box: 226, 421, 13, 11
# Word: °, Confidence: 31, Bounding Box: 345, 426, 7, 5
# Word: <coceceercareer, Confidence: 0, Bounding Box: 160, 432, 168, 5
# Word: |, Confidence: 51, Bounding Box: 326, 423, 9, 31
# Word: Outen, Confidence: 29, Bounding Box: 360, 436, 28, 7
# Word: Orta, Confidence: 3, Bounding Box: 398, 435, 28, 7
# Word: Tresay, Confidence: 0, Bounding Box: 166, 440, 31, 6
# Word: tahoe, Confidence: 26, Bounding Box: 204, 440, 111, 8
# Word: on, Confidence: 37, Bounding Box: 262, 428, 12, 28
# Word: rhanerne, Confidence: 0, Bounding Box: 278, 440, 37, 8
# Word: ‘ompolendeomasstoucnyse, Confidence: 0, Bounding Box: 165, 449, 73, 9
# Word: Soseons, Confidence: 0, Bounding Box: 264, 449, 57, 9
# Word: |, Confidence: 49, Bounding Box: 329, 437, 17, 28
# Word: Lovelt, Confidence: 0, Bounding Box: 359, 447, 28, 8
# Word: rbat, Confidence: 0, Bounding Box: 391, 445, 35, 9
# Word: NN, Confidence: 14, Bounding Box: 71, 453, 25, 17
# Word: ya, Confidence: 11, Bounding Box: 122, 462, 17, 6
# Word: eee, Confidence: 34, Bounding Box: 166, 459, 114, 8
# Word: tar, Confidence: 28, Bounding Box: 378, 457, 38, 9

# %%
nutrition.plain_text_ocr()
# Out:
# Nutrition Facts
#
# onan a
#
# about 5 servings per container | potas Mu
# Serving size _ 3/4 cup (170g) |i
# |
#
# Ealories” 100]...
#
# Se Datty Veneer} north
# Using ng 8
# sonst
#
# Total Fat 259 3%
# Satualed Fat 1.59
# \ “Trans Fat 0g
# holesterol ng
# Sodium 1109 3%| 6
#
# | 808
#
# Detar Fiber 0g 0%
# \ Total Sugars 129
#
# \ Incas Og Acied Suars 0%
# \ Proteina 16%
# / Wann 17mg © Cabin 2g 2%
# WZ ientimgits © Potassum 360m 8
# 1\ ain 106 1% °
# <coceceercareer | Outen Orta
#
# Tresay tahoe on rhanerne
# ‘ompolendeomasstoucnyse Soseons | Lovelt rbat
#
# NN ya eee tar
